# %%
input_root="../szunyog_hangok_25_01_14"
output_root="../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier"

model_path = "c:/PROJECTS/szunyog/b_mosquito/b_mosquito_simple_classifier-1_checkpoints/best_loss_99.pth"
b_selfattention=True
classification_threshold=0.9
b_write_csv=True
b_save_segments=True

# %%
import os
from pathlib import Path
from pydub import AudioSegment
import os
import numpy as np
import librosa
import glob
import pandas as pd
import numpy as np

import torch
import torch.nn.functional as F

import dataPreprocess
import model_modified

import torch
import torch.nn as nn
from torch.utils.data import DataLoader
import time

# Támogatott hangfájl formátumok
supported_formats = [".wav"]

# Az output mappa létrehozása, ha nem létezik
os.makedirs(output_root, exist_ok=True)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#device="cpu"
print(device)
# Out:
# cuda

# %%
# Load pretrained model and processor
label2id = {'not':0, 'mosquito':1}
id2label = {v: k for k, v in label2id.items()}

# Model betöltése
resnet_model = model_modified.resnet18_attention(1, len(label2id), b_selfattention=b_selfattention)
resnet_model = resnet_model.to(device)

resnet_model.load_state_dict(torch.load(model_path))
resnet_model.eval()

resnet_model
# Out:
# ResAtt(
#   (encoder): ResNetEncoder(
#     (gate): Sequential(
#       (0): Conv2d(1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     )
#     (blocks): ModuleList(
#       (0): ResNetLayer(
#         (blocks): Sequential(
#           (0): ResNetBasicBlock(
#             (blocks): Sequential(
#               (0): Sequential(
#                 (conv): Conv2dAuto(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (1): ReLU()
#               (2): Sequential(
#                 (conv): Conv2dAuto(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (shortcut): None
#           )
#           (1): ResNetBasicBlock(
#             (blocks): Sequential(
#               (0): Sequential(
#                 (conv): Conv2dAuto(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (1): ReLU()
#               (2): Sequential(
#                 (conv): Conv2dAuto(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (shortcut): None
#           )
#         )
#         (self_attention_block): SelfAttentionBlock(
#           (conv_f): Conv1d(64, 8, kernel_size=(1,), stride=(1,))
#           (conv_g): Conv1d(64, 8, kernel_size=(1,), stride=(1,))
#           (conv_h): Conv1d(64, 64, kernel_size=(1,), stride=(1,))
#           (softmax): Softmax(dim=-1)
#         )
#       )
#       (1): ResNetLayer(
#         (blocks): Sequential(
#           (0): ResNetBasicBlock(
#             (blocks): Sequential(
#               (0): Sequential(
#                 (conv): Conv2dAuto(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (1): ReLU()
#               (2): Sequential(
#                 (conv): Conv2dAuto(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (shortcut): Sequential(
#               (conv): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#               (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (1): ResNetBasicBlock(
#             (blocks): Sequential(
#               (0): Sequential(
#                 (conv): Conv2dAuto(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (1): ReLU()
#               (2): Sequential(
#                 (conv): Conv2dAuto(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (shortcut): None
#           )
#         )
#         (self_attention_block): SelfAttentionBlock(
#           (conv_f): Conv1d(128, 16, kernel_size=(1,), stride=(1,))
#           (conv_g): Conv1d(128, 16, kernel_size=(1,), stride=(1,))
#           (conv_h): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#           (softmax): Softmax(dim=-1)
#         )
#       )
#       (2): ResNetLayer(
#         (blocks): Sequential(
#           (0): ResNetBasicBlock(
#             (blocks): Sequential(
#               (0): Sequential(
#                 (conv): Conv2dAuto(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (1): ReLU()
#               (2): Sequential(
#                 (conv): Conv2dAuto(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (shortcut): Sequential(
#               (conv): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#               (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (1): ResNetBasicBlock(
#             (blocks): Sequential(
#               (0): Sequential(
#                 (conv): Conv2dAuto(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (1): ReLU()
#               (2): Sequential(
#                 (conv): Conv2dAuto(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (shortcut): None
#           )
#         )
#         (self_attention_block): SelfAttentionBlock(
#           (conv_f): Conv1d(256, 32, kernel_size=(1,), stride=(1,))
#           (conv_g): Conv1d(256, 32, kernel_size=(1,), stride=(1,))
#           (conv_h): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#           (softmax): Softmax(dim=-1)
#         )
#       )
#       (3): ResNetLayer(
#         (blocks): Sequential(
#           (0): ResNetBasicBlock(
#             (blocks): Sequential(
#               (0): Sequential(
#                 (conv): Conv2dAuto(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (1): ReLU()
#               (2): Sequential(
#                 (conv): Conv2dAuto(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (shortcut): Sequential(
#               (conv): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#               (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (1): ResNetBasicBlock(
#             (blocks): Sequential(
#               (0): Sequential(
#                 (conv): Conv2dAuto(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (1): ReLU()
#               (2): Sequential(
#                 (conv): Conv2dAuto(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (shortcut): None
#           )
#         )
#         (self_attention_block): SelfAttentionBlock(
#           (conv_f): Conv1d(512, 64, kernel_size=(1,), stride=(1,))
#           (conv_g): Conv1d(512, 64, kernel_size=(1,), stride=(1,))
#           (conv_h): Conv1d(512, 512, kernel_size=(1,), stride=(1,))
#           (softmax): Softmax(dim=-1)
#         )
#       )
#     )
#   )
#   (decoder): ResnetDecoder(
#     (avg): AdaptiveAvgPool2d(output_size=(1, 1))
#     (decoder): Sequential(
#       (0): Linear(in_features=512, out_features=128, bias=True)
#       (1): ReLU()
#       (2): Dropout(p=0.3, inplace=False)
#       (3): Linear(in_features=128, out_features=2, bias=True)
#       (4): LogSoftmax(dim=1)
#     )
#   )
# )

# %%
def split_audio_chunks(input_file):
    """
    Hangfájl beolvasása, csatornák számának meghatározása, darabolás 1 másodperces darabokra, 0.5 másodperces átfedéssel.
    """
    chunks = []
    metadata = []
    try:
        # Hangfájl betöltése
        audio = AudioSegment.from_file(input_file)

        # Csatornák számának meghatározása
        num_channels = audio.channels
        print(f"Fájl: {input_file}, Csatornák száma: {num_channels}")
        

        # Minden csatorna szétválasztása
        separated_channels = audio.split_to_mono()

        for channel_index, channel_audio in enumerate(separated_channels):

            # Konvertálás 8kHz-re
            #channel_audio = channel_audio.set_frame_rate(8000)
            channel_audio = channel_audio.set_frame_rate(16000)

            duration_ms = len(channel_audio)

            # x másodperces ablak, y másodperces lépés
            window_size = 1000  # milliszekundumban
            step_size = 500     # milliszekundumban

            for start_ms in range(0, duration_ms - window_size + 1, step_size):
                end_ms = start_ms + window_size
                chunk = channel_audio[start_ms:end_ms]
                chunks.append(chunk)

                # Metadata rögzítése
                metadata.append({
                    "file": os.path.basename(input_file),
                    "channel": channel_index + 1,
                    "start_ms": start_ms,
                    "end_ms": end_ms
                })
            #break # channel
            
    except Exception as e:
        print(f"Hiba a darabolás során: {input_file} - {e}")

    return chunks, metadata

# %%
def getFeature(y, sr=8000, top_db=80):
    """
    Funkció a spektrális jellemzők kiszámítására közvetlenül az audio adatból.
    """
    # Audio padding (2 másodperces minimum hossz)
    y = np.pad(y, int(np.ceil((2 * sr - y.shape[0]) / 2)), mode='reflect')
    
    # Melspectrogram kiszámítása
    spec = librosa.feature.melspectrogram(y=y, sr=sr, n_fft=256, hop_length=64)
    spec = librosa.power_to_db(spec, top_db=top_db)

    # Normalizálás 0-255 közé
    spec_min, spec_max = spec.min(), spec.max()
    spec = 255 * (spec - spec_min) / (spec_max - spec_min)
    spec = spec.astype(np.uint8)
    spec = spec[np.newaxis, ...]  # Csatorna dimenzió hozzáadása
    return spec

# %%
import torchaudio.transforms as T
resample_transform = None

def torch_resample(y, orig_sr, target_sr):
    """
    Resampling torchaudio segítségével.
    """
    global resample_transform
    if resample_transform is None:
        resample_transform = T.Resample(orig_freq=orig_sr, new_freq=target_sr)
    
    return resample_transform(torch.tensor(y)).numpy()

from scipy.signal import resample

def fast_resample(y, orig_sr, target_sr):
    """
    Resampling scipy.signal.resample használatával.
    """
    num_samples = int(len(y) * target_sr / orig_sr)
    return resample(y, num_samples)

# %%
#!pip install samplerate
import samplerate

def samplerate_resample(y, orig_sr, target_sr):
    """
    Resampling samplerate használatával.
    """
    ratio = target_sr / orig_sr
    #return samplerate.resample(y, ratio, 'sinc_fastest')
    return samplerate.resample(y, ratio, 'sinc_medium')

# %%
def predict_audio_chunk(chunk, model, target_sr=8000, threshold=0.5):
    """
    Szűrőfüggvény, amely az adott hangdarabról eldönti, hogy tartalmaz-e szúnyoghangot.
    """

    # Audio adatok kinyerése a chunkból
    data = chunk.get_array_of_samples()
    dtype = data.typecode  # Az array típusa, pl. 'h' vagy 'i'
    y = np.array(data, dtype=np.float32)  # Mindig float32-be alakítjuk

    # Normalizálás az adat típusától függően
    if dtype == 'h':  # 16 bites integer
        y = y / (2**15)  # Normálás -1 és 1 közé
    elif dtype == 'i':  # 32 bites integer
        y = y / (2**31)  # Normálás -1 és 1 közé
    else:
        raise ValueError(f"Nem támogatott adatformátum: {dtype}")

    sr = chunk.frame_rate

    # Downsampling, ha szükséges
    if sr != target_sr:
        #y = librosa.resample(y, orig_sr=sr, target_sr=target_sr)
        #y = torch_resample(y, sr, target_sr)
        #y = fast_resample(y, sr, target_sr)
        y = samplerate_resample(y, sr, target_sr)
        sr = target_sr

    # Feature extraction
    spec = getFeature(y, sr=sr)


    # Tenzor előkészítése PyTorch modellhez
    inputs = torch.tensor(spec, dtype=torch.float32).unsqueeze(0)  # Batch dimenzió hozzáadása
    inputs = inputs.to(device)
    
    # Modell predikció
    with torch.no_grad():
        logits = model(inputs)

    # Valószínűségek kiszámítása softmax-szal
    probabilities = torch.softmax(logits, dim=-1)
    class_1_probabilities = probabilities[:, 1]

    # Szűrés küszöbérték alapján
    thresholded = class_1_probabilities >= threshold

    return thresholded[0]

# %%
def anal_chunks(chunks, output_dir, base_filename, metadata, model, classification_threshold=0.5, b_save=False):
    """
    Darabok mentése a megadott mappába sorszámozva.
    """
    os.makedirs(output_dir, exist_ok=True)
    not_selected_dir = os.path.join(os.path.dirname(output_dir), os.path.basename(output_dir) + "_not_selected")
    os.makedirs(not_selected_dir, exist_ok=True)

    #speech_dir = os.path.join(os.path.dirname(output_dir), os.path.basename(output_dir) + "_speech")
    #os.makedirs(speech_dir, exist_ok=True)

    sound_idxs=[]

    for idx, chunk in enumerate(chunks):
        md=metadata[idx]

        ch=md['channel']
        start=str(int(md['start_ms']))
        
        #if filter_speech(chunk):
        #    if b_save:
        #        chunk_speech_file = os.path.join(speech_dir, f"{base_filename}_{ch}_{start}.wav")            
                #chunk.export(chunk_speech_file, format="wav", parameters=["-ar", "16000", "-ac", "1", "-sample_fmt", "s16"])

        #    if idx % 50 == 0:
        #        pass
                #print(f"{idx}: Mentett darab (BESZÉD): {chunk_speech_file}")
        #    continue
        
        if predict_audio_chunk(chunk, model, threshold=classification_threshold):
            sound_idxs.append(idx)
            chunk_output_file = os.path.join(output_dir, f"{base_filename}_{ch}_{start}.wav")
            #print(f"{idx}: Mentett darab (SZÚNYOG HANG): {chunk_output_file}")

            if b_save:
                chunk.export(chunk_output_file, format="wav", parameters=["-ar", "16000", "-ac", "1", "-sample_fmt", "s16"])

                if idx % 50 == 0:
                    pass
                    print(f"{idx}: Mentett darab (SZÚNYOG HANG): {chunk_output_file}")
        else:
            if b_save:
                not_selected_file = os.path.join(not_selected_dir, f"{base_filename}_{ch}_{start}.wav")
                #chunk.export(not_selected_file, format="wav", parameters=["-ar", "16000", "-ac", "1", "-sample_fmt", "s16"])

            if idx % 50 == 0:
                pass
                #print(f"{idx}: Nem kiválasztott darab: {not_selected_file}")

        #break
        
    return sound_idxs

# %%
fns=glob.glob(os.path.join(input_root,"*.wav"))

model=resnet_model

# Időmérés kezdete
start_time = time.time()

for idx, input_fn in enumerate(fns):

    base_filename=os.path.basename(input_fn)
    output_file = os.path.join(output_root, f"{base_filename[:-4]}.csv")

    
    #Ha az output fájl már létezik, folytatjuk a következő fájllal
    if os.path.exists(output_file):
        print(f"allready done: {input_fn}")
        continue

    # Darabolás és szűrés
    #print("split begun")
    chunks, metadata = split_audio_chunks(input_fn)
    #print("split finished")


    if len(chunks)>0:
        # indexben a szunyog szegmensek, es a fuggveny wav-okat is kiir b_save=1 esetben
        sound_idxs=anal_chunks(chunks, output_root, base_filename, metadata, model, classification_threshold=classification_threshold, b_save=b_save_segments)

        if b_write_csv:
            if len(sound_idxs)>0:
                # Metadata DataFrame létrehozása
                out_df = pd.DataFrame(metadata)
                
                # Szűrés az analizált indexek alapján
                out_df = out_df.iloc[sound_idxs]
            
                # Eredmények mentése fájlba
                out_df.to_csv(output_file, index=False)
            else:
                # Üres csv
                with open(output_file, mode="w") as file:
                    file.write("file,channel,start_ms,end_ms\n")
                print("nem találtam szúnyoghangot.")

end_time = time.time()
print(f"befejezve, idő: {end_time - start_time:.6f} másodperc")
# Out:
# Fájl: ../szunyog_hangok_25_01_14\Test0194_I.wav, Csatornák száma: 2
# 200: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0194_I.wav_1_100000.wav
# 300: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0194_I.wav_1_150000.wav
# 350: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0194_I.wav_1_175000.wav
# Fájl: ../szunyog_hangok_25_01_14\Test0194_M.wav, Csatornák száma: 2
# Fájl: ../szunyog_hangok_25_01_14\Test0195_I.wav, Csatornák száma: 2
# Fájl: ../szunyog_hangok_25_01_14\Test0195_M.wav, Csatornák száma: 2
# 450: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0195_M.wav_1_225000.wav
# Fájl: ../szunyog_hangok_25_01_14\Test0196_I.wav, Csatornák száma: 2
# 200: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0196_I.wav_1_100000.wav
# 500: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0196_I.wav_1_250000.wav
# 900: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0196_I.wav_1_450000.wav
# Fájl: ../szunyog_hangok_25_01_14\Test0196_M.wav, Csatornák száma: 2
# Fájl: ../szunyog_hangok_25_01_14\Test0197_I.wav, Csatornák száma: 2
# 250: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0197_I.wav_1_125000.wav
# 350: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0197_I.wav_1_175000.wav
# 550: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0197_I.wav_1_275000.wav
# 850: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0197_I.wav_1_425000.wav
# 1200: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0197_I.wav_1_600000.wav
# 1650: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0197_I.wav_2_163500.wav
# 1900: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0197_I.wav_2_288500.wav
# 2300: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0197_I.wav_2_488500.wav
# Fájl: ../szunyog_hangok_25_01_14\Test0197_M.wav, Csatornák száma: 2
# 550: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0197_M.wav_1_275000.wav
# 1200: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0197_M.wav_1_600000.wav
# 1600: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0197_M.wav_2_138500.wav
# 1650: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0197_M.wav_2_163500.wav
# 1700: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0197_M.wav_2_188500.wav
# 2100: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0197_M.wav_2_388500.wav
# Fájl: ../szunyog_hangok_25_01_14\Test0198_I.wav, Csatornák száma: 2
# 450: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0198_I.wav_1_225000.wav
# Fájl: ../szunyog_hangok_25_01_14\Test0198_M.wav, Csatornák száma: 2
# Fájl: ../szunyog_hangok_25_01_14\Test0199_I.wav, Csatornák száma: 2
# Fájl: ../szunyog_hangok_25_01_14\Test0199_M.wav, Csatornák száma: 2
# Fájl: ../szunyog_hangok_25_01_14\Test0200_I.wav, Csatornák száma: 2
# Fájl: ../szunyog_hangok_25_01_14\Test0200_M.wav, Csatornák száma: 2
# nem találtam szúnyoghangot.
# Fájl: ../szunyog_hangok_25_01_14\Test0201_I.wav, Csatornák száma: 2
# 2900: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0201_I.wav_2_643000.wav
# Fájl: ../szunyog_hangok_25_01_14\Test0201_M.wav, Csatornák száma: 2
# Fájl: ../szunyog_hangok_25_01_14\Test0202_I.wav, Csatornák száma: 2
# Fájl: ../szunyog_hangok_25_01_14\Test0202_M.wav, Csatornák száma: 2
# Fájl: ../szunyog_hangok_25_01_14\Test0203_I.wav, Csatornák száma: 2
# nem találtam szúnyoghangot.
# Fájl: ../szunyog_hangok_25_01_14\Test0203_M.wav, Csatornák száma: 2
# nem találtam szúnyoghangot.
# Fájl: ../szunyog_hangok_25_01_14\Test0204_I.wav, Csatornák száma: 2
# Fájl: ../szunyog_hangok_25_01_14\Test0204_M.wav, Csatornák száma: 2
# Fájl: ../szunyog_hangok_25_01_14\Test0205_I.wav, Csatornák száma: 2
# 1000: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0205_I.wav_1_500000.wav
# Fájl: ../szunyog_hangok_25_01_14\Test0205_M.wav, Csatornák száma: 2
# 1000: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0205_M.wav_1_500000.wav
# Fájl: ../szunyog_hangok_25_01_14\Test0206_I.wav, Csatornák száma: 2
# Fájl: ../szunyog_hangok_25_01_14\Test0206_M.wav, Csatornák száma: 2
# Fájl: ../szunyog_hangok_25_01_14\Test0207_I.wav, Csatornák száma: 2
# Fájl: ../szunyog_hangok_25_01_14\Test0207_M.wav, Csatornák száma: 2
# Fájl: ../szunyog_hangok_25_01_14\Test0208_I.wav, Csatornák száma: 2
# Fájl: ../szunyog_hangok_25_01_14\Test0208_M.wav, Csatornák száma: 2
# nem találtam szúnyoghangot.
# Fájl: ../szunyog_hangok_25_01_14\Test0209_I.wav, Csatornák száma: 2
# 300: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0209_I.wav_1_150000.wav
# Fájl: ../szunyog_hangok_25_01_14\Test0209_M.wav, Csatornák száma: 2
# Fájl: ../szunyog_hangok_25_01_14\Test0210_I.wav, Csatornák száma: 2
# Fájl: ../szunyog_hangok_25_01_14\Test0210_M.wav, Csatornák száma: 2
# 1850: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0210_M.wav_1_925000.wav
# Fájl: ../szunyog_hangok_25_01_14\Test0211_M.wav, Csatornák száma: 2
# nem találtam szúnyoghangot.
# Fájl: ../szunyog_hangok_25_01_14\Test0212_I.wav, Csatornák száma: 2
# Fájl: ../szunyog_hangok_25_01_14\Test0212_M.wav, Csatornák száma: 2
# Fájl: ../szunyog_hangok_25_01_14\Test0213_I.wav, Csatornák száma: 2
# 650: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0213_I.wav_1_325000.wav
# 1200: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0213_I.wav_1_600000.wav
# 1300: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0213_I.wav_1_650000.wav
# 2000: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0213_I.wav_2_331000.wav
# 2350: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0213_I.wav_2_506000.wav
# 2450: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test
Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0562.wav_3_660000.wav
# 6100: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0562.wav_3_685000.wav
# 6150: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0562.wav_3_710000.wav
# 6200: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0562.wav_3_735000.wav
# 6250: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0562.wav_3_760000.wav
# 6300: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0562.wav_3_785000.wav
# 6350: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0562.wav_3_810000.wav
# 6400: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0562.wav_3_835000.wav
# 6500: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0562.wav_3_885000.wav
# 6600: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0562.wav_3_935000.wav
# 6700: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0562.wav_3_985000.wav
# 7000: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0562.wav_3_1135000.wav
# 7500: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0562.wav_4_202500.wav
# 7700: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0562.wav_4_302500.wav
# 7750: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0562.wav_4_327500.wav
# 7800: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0562.wav_4_352500.wav
# 7850: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0562.wav_4_377500.wav
# 7950: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0562.wav_4_427500.wav
# 8050: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0562.wav_4_477500.wav
# 8200: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0562.wav_4_552500.wav
# 8250: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0562.wav_4_577500.wav
# 8300: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0562.wav_4_602500.wav
# 8450: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0562.wav_4_677500.wav
# 8500: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0562.wav_4_702500.wav
# 8550: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0562.wav_4_727500.wav
# 8600: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0562.wav_4_752500.wav
# 8650: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0562.wav_4_777500.wav
# 8700: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0562.wav_4_802500.wav
# 8750: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0562.wav_4_827500.wav
# 8800: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0562.wav_4_852500.wav
# 8850: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0562.wav_4_877500.wav
# 8900: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0562.wav_4_902500.wav
# 8950: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0562.wav_4_927500.wav
# 9050: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0562.wav_4_977500.wav
# Fájl: ../szunyog_hangok_25_01_14\Test0563_I.wav, Csatornák száma: 2
# 200: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0563_I.wav_1_100000.wav
# 300: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0563_I.wav_1_150000.wav
# 750: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0563_I.wav_1_375000.wav
# 900: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0563_I.wav_1_450000.wav
# 1600: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0563_I.wav_1_800000.wav
# 1800: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0563_I.wav_1_900000.wav
# 2000: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0563_I.wav_1_1000000.wav
# 2250: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0563_I.wav_1_1125000.wav
# 2600: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0563_I.wav_2_106500.wav
# 3600: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0563_I.wav_2_606500.wav
# 4400: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0563_I.wav_2_1006500.wav
# 4500: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0563_I.wav_2_1056500.wav
# Fájl: ../szunyog_hangok_25_01_14\Test0563_M.wav, Csatornák száma: 2
# 200: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0563_M.wav_1_100000.wav
# 400: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0563_M.wav_1_200000.wav
# 750: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0563_M.wav_1_375000.wav
# 950: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0563_M.wav_1_475000.wav
# 1000: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0563_M.wav_1_500000.wav
# 1050: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0563_M.wav_1_525000.wav
# 1350: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0563_M.wav_1_675000.wav
# 1400: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0563_M.wav_1_700000.wav
# 2250: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0563_M.wav_1_1125000.wav
# 2300: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0563_M.wav_1_1150000.wav
# 2600: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0563_M.wav_2_106500.wav
# 3700: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0563_M.wav_2_656500.wav
# 3800: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0563_M.wav_2_706500.wav
# 4500: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0563_M.wav_2_1056500.wav
# Fájl: ../szunyog_hangok_25_01_14\Test0564_I.wav, Csatornák száma: 2
# Fájl: ../szunyog_hangok_25_01_14\Test0564_M.wav, Csatornák száma: 2
# Fájl: ../szunyog_hangok_25_01_14\Test0565_I.wav, Csatornák száma: 2
# Fájl: ../szunyog_hangok_25_01_14\Test0565_M.wav, Csatornák száma: 2
# Fájl: ../szunyog_hangok_25_01_14\Test0566_I.wav, Csatornák száma: 2
# 700: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0566_I.wav_1_350000.wav
# 1100: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0566_I.wav_1_550000.wav
# 2700: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0566_I.wav_2_673500.wav
# Fájl: ../szunyog_hangok_25_01_14\Test0566_M.wav, Csatornák száma: 2
# Fájl: ../szunyog_hangok_25_01_14\Test0567_I.wav, Csatornák száma: 2
# Fájl: ../szunyog_hangok_25_01_14\Test0567_M.wav, Csatornák száma: 2
# 0: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0567_M.wav_1_0.wav
# Fájl: ../szunyog_hangok_25_01_14\Test0568_I.wav, Csatornák száma: 2
# nem találtam szúnyoghangot.
# Fájl: ../szunyog_hangok_25_01_14\Test0568_M.wav, Csatornák száma: 2
# nem találtam szúnyoghangot.
# Fájl: ../szunyog_hangok_25_01_14\Test0569_I.wav, Csatornák száma: 2
# Fájl: ../szunyog_hangok_25_01_14\Test0569_M.wav, Csatornák száma: 2
# nem találtam szúnyoghangot.
# Fájl: ../szunyog_hangok_25_01_14\Test0570_I.wav, Csatornák száma: 2
# 50: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0570_I.wav_1_25000.wav
# 150: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0570_I.wav_1_75000.wav
# 200: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0570_I.wav_1_100000.wav
# 250: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0570_I.wav_1_125000.wav
# 850: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0570_I.wav_1_425000.wav
# 1950: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0570_I.wav_2_316500.wav
# 2200: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0570_I.wav_2_441500.wav
# 2300: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0570_I.wav_2_491500.wav
# Fájl: ../szunyog_hangok_25_01_14\Test0570_M.wav, Csatornák száma: 2
# 350: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0570_M.wav_1_175000.wav
# 550: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0570_M.wav_1_275000.wav
# 2450: Mentett darab (SZÚNYOG HANG): ../szunyog_hangok_25_01_14_preprocessed_database_simple_classifier\Test0570_M.wav_2_566500.wav
# Fájl: ../szunyog_hangok_25_01_14\Test201_I.wav, Csatornák száma: 2
# nem találtam szúnyoghangot.
# Fájl: ../szunyog_hangok_25_01_14\Test439_M.wav, Csatornák száma: 2
# befejezve, idő: 66741.105341 másodperc
